# %% [markdown]
# # 4.4 EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load Data
df = pd.read_csv('ai4i.csv') # Make sure this matches your file name

# ==========================================
# FIGURE 4.1: HISTOGRAM GRID
# ==========================================
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
sns.histplot(df['Air temperature [K]'], kde=True, ax=axes[0, 0], color='skyblue')
axes[0, 0].set_title('Air Temperature Distribution')

sns.histplot(df['Process temperature [K]'], kde=True, ax=axes[0, 1], color='orange')
axes[0, 1].set_title('Process Temperature Distribution')

sns.histplot(df['Rotational speed [rpm]'], kde=True, ax=axes[1, 0], color='green')
axes[1, 0].set_title('Rotational Speed (Right Skewed)')

sns.histplot(df['Torque [Nm]'], kde=True, ax=axes[1, 1], color='red')
axes[1, 1].set_title('Torque Distribution (Normal)')

plt.tight_layout()
plt.savefig('Figure_4.1_Histograms.png') # Saves the image
plt.show()

# ==========================================
# FIGURE 4.2: PHYSICS PROOF (SCATTER PLOT)
# ==========================================
plt.figure(figsize=(8, 6))
# Plotting Speed vs Torque
sns.scatterplot(x=df['Rotational speed [rpm]'], y=df['Torque [Nm]'], alpha=0.5)
plt.title('Physics Validation: Torque vs. Speed')
plt.xlabel('Rotational Speed [rpm]')
plt.ylabel('Torque [Nm]')
plt.grid(True, linestyle='--', alpha=0.6)

plt.savefig('Figure_4.2_Physics_Proof.png') # Saves the image
plt.show()
print("Look at Figure 4.2: Do you see the downward curve? That proves P = Torque * Speed.")

# ==========================================
# FIGURE 4.3: CORRELATION HEATMAP
# ==========================================
plt.figure(figsize=(10, 8))
# Select only numerical columns for correlation
numerical_cols = ['Air temperature [K]', 'Process temperature [K]',
                  'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
corr_matrix = df[numerical_cols].corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Pearson Correlation Heatmap')

plt.savefig('Figure_4.3_Correlation_Matrix.png') # Saves the image
plt.show()
# Out:
# Look at Figure 4.2: Do you see the downward curve? That proves P = Torque * Speed.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 1. Setup for "Academic Paper" Style
# This makes fonts bigger and lines thicker for better visibility in LaTeX
sns.set_context("talk", font_scale=1.1)
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'

# 2. Load Data (Ensure file name matches yours)
df = pd.read_csv('ai4i.csv')

# ========================================================
# FIGURE 4.1: HISTOGRAM GRID (Distributions)
# ========================================================
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

# Air Temp
sns.histplot(df['Air temperature [K]'], kde=True, ax=axes[0, 0], color='#1f77b4', element="step")
axes[0, 0].set_title('Air Temperature Distribution', fontsize=16, pad=15)
axes[0, 0].set_xlabel('Temperature [K]', fontsize=14)

# Process Temp
sns.histplot(df['Process temperature [K]'], kde=True, ax=axes[0, 1], color='#ff7f0e', element="step")
axes[0, 1].set_title('Process Temperature Distribution', fontsize=16, pad=15)
axes[0, 1].set_xlabel('Temperature [K]', fontsize=14)

# Rotational Speed
sns.histplot(df['Rotational speed [rpm]'], kde=True, ax=axes[1, 0], color='#2ca02c', element="step")
axes[1, 0].set_title('Rotational Speed (Right Skewed)', fontsize=16, pad=15)
axes[1, 0].set_xlabel('Speed [RPM]', fontsize=14)

# Torque
sns.histplot(df['Torque [Nm]'], kde=True, ax=axes[1, 1], color='#d62728', element="step")
axes[1, 1].set_title('Torque Distribution (Normal)', fontsize=16, pad=15)
axes[1, 1].set_xlabel('Torque [Nm]', fontsize=14)

plt.tight_layout()
plt.savefig('Figure_4.1_Histograms_HighRes.png', dpi=300, bbox_inches='tight')
print("Generated Figure 4.1")

# ========================================================
# FIGURE 4.2: PHYSICS PROOF (Scatter Plot)
# ========================================================
plt.figure(figsize=(10, 7))
sns.scatterplot(
    x=df['Rotational speed [rpm]'],
    y=df['Torque [Nm]'],
    alpha=0.6,
    edgecolor=None,
    color='#9467bd'
)
plt.title('Physics Validation: Torque vs. Speed\n(Conservation of Power: P = τ × ω)', fontsize=18, pad=20)
plt.xlabel('Rotational Speed [RPM]', fontsize=16)
plt.ylabel('Torque [Nm]', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)

plt.savefig('Figure_4.2_Physics_Proof_HighRes.png', dpi=300, bbox_inches='tight')
print("Generated Figure 4.2")

# ========================================================
# FIGURE 4.3: CORRELATION HEATMAP
# ========================================================
plt.figure(figsize=(10, 8))
numerical_cols = ['Air temperature [K]', 'Process temperature [K]',
                  'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
corr_matrix = df[numerical_cols].corr()

# Rename columns for cleaner heatmap labels
clean_labels = ['Air Temp', 'Proc Temp', 'RPM', 'Torque', 'Tool Wear']
corr_matrix.columns = clean_labels
corr_matrix.index = clean_labels

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    linewidths=1,
    annot_kws={"size": 14}, # Large numbers inside boxes
    cbar_kws={'label': 'Pearson Correlation'}
)
plt.title('Feature Correlation Matrix', fontsize=18, pad=20)

plt.savefig('Figure_4.3_Correlation_Matrix_HighRes.png', dpi=300, bbox_inches='tight')
print("Generated Figure 4.3")

# ========================================================
# FIGURE 4.4: CLASS IMBALANCE (Pie Chart)
# ========================================================
plt.figure(figsize=(8, 8))
counts = df['Machine failure'].value_counts()
labels = [f'Normal\n({counts[0]})', f'Failure\n({counts[1]})']
colors = ['#66b3ff', '#ff9999'] # Soft Blue and Red

plt.pie(
    counts,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',
    startangle=30,
    textprops={'fontsize': 16, 'weight': 'bold'},
    explode=(0, 0.2), # Explode the failure slice to highlight it
    shadow=True
)
plt.title('Class Imbalance: Normal vs. Failure', fontsize=18)

plt.savefig('Figure_4.4_Class_Imbalance_HighRes.png', dpi=300, bbox_inches='tight')
print("Generated Figure 4.4")

# ========================================================
# FIGURE 4.5: FAILURE MODE BREAKDOWN (Bar Chart)
# ========================================================
# Calculating counts for specific failure columns
failures = {
    'TWF (Tool Wear)': df['TWF'].sum(),
    'HDF (Heat Dissipation)': df['HDF'].sum(),
    'PWF (Power)': df['PWF'].sum(),
    'OSF (Overstrain)': df['OSF'].sum(),
    'RNF (Random)': df['RNF'].sum()
}

plt.figure(figsize=(12, 7))
sns.barplot(x=list(failures.keys()), y=list(failures.values()), palette='viridis')

plt.title('Distribution of Specific Failure Modes', fontsize=18, pad=20)
plt.ylabel('Count of Failures', fontsize=16)
plt.xlabel('Failure Type', fontsize=16)
plt.xticks(rotation=0, fontsize=14) # Keep labels horizontal if possible

# Add numbers on top of bars
for i, v in enumerate(failures.values()):
    plt.text(i, v + 2, str(v), ha='center', fontsize=14, fontweight='bold')

plt.savefig('Figure_4.5_Failure_Modes_HighRes.png', dpi=300, bbox_inches='tight')
print("Generated Figure 4.5")
# Out:
# Generated Figure 4.1
# Generated Figure 4.2
# Generated Figure 4.3
# Generated Figure 4.4
# /tmp/ipython-input-1340387446.py:128: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(failures.keys()), y=list(failures.values()), palette='viridis')
# Generated Figure 4.5

# %% [markdown]
# # 4.5 4.5 Target Variable Analysis: The Imbalance Challenge

# %% [markdown]
# 4.5.2 Granular Failure Mode Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load Data (Make sure the filename matches yours)
df = pd.read_csv('ai4i.csv')

# 2. Setup Style for Publication
sns.set_context("talk")  # Big font
sns.set_style("whitegrid") # Clean background

# 3. Calculate the counts for each failure type
# The dataset has '1' in these columns if that specific failure occurred
failure_data = {
    'HDF\n(Heat)': df['HDF'].sum(),
    'OSF\n(Overstrain)': df['OSF'].sum(),
    'PWF\n(Power)': df['PWF'].sum(),
    'TWF\n(Tool Wear)': df['TWF'].sum(),
    'RNF\n(Random)': df['RNF'].sum()
}

# Convert to a DataFrame for easier plotting with Seaborn
plot_df = pd.DataFrame(list(failure_data.items()), columns=['Failure Type', 'Count'])

# Sort so the "Dominant" ones (HDF, OSF) are easy to compare, or keep fixed order
plot_df = plot_df.sort_values(by='Count', ascending=False)

# 4. Generate the Bar Chart
plt.figure(figsize=(12, 7))

# Create Bar Plot
ax = sns.barplot(x='Failure Type', y='Count', data=plot_df, palette='magma', hue='Failure Type', legend=False)

# 5. Add the actual numbers on top of the bars (Crucial for Analysis)
for i, v in enumerate(plot_df['Count']):
    ax.text(i, v + 3, str(v), ha='center', fontsize=16, fontweight='bold')

# 6. Formatting Labels
plt.title('Figure 4.5: Distribution of Specific Failure Modes', fontsize=18, fontweight='bold', pad=20)
plt.ylabel('Frequency (Count)', fontsize=15, fontweight='bold')
plt.xlabel('Failure Mode', fontsize=15, fontweight='bold')

# 7. Save High-Res Image
plt.savefig('Figure_4.5_Failure_Modes_BarChart.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"HDF Count: {failure_data['HDF\n(Heat)']}")
print(f"OSF Count: {failure_data['OSF\n(Overstrain)']}")
# Out:
# HDF Count: 115
# OSF Count: 98

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load Data
df = pd.read_csv('ai4i.csv')

# 2. Setup Style
sns.set_context("talk")
sns.set_style("whitegrid")

# 3. Calculate Counts
# We define the keys exactly here
failure_data = {
    'HDF\n(Heat)': df['HDF'].sum(),
    'OSF\n(Overstrain)': df['OSF'].sum(),
    'PWF\n(Power)': df['PWF'].sum(),
    'TWF\n(Tool Wear)': df['TWF'].sum(),
    'RNF\n(Random)': df['RNF'].sum()
}

# Convert to DataFrame
plot_df = pd.DataFrame(list(failure_data.items()), columns=['Failure Type', 'Count'])
plot_df = plot_df.sort_values(by='Count', ascending=False)

# 4. Generate Bar Chart
plt.figure(figsize=(12, 7))

# FIX 1: Added `hue` and `legend=False` to fix the warning
ax = sns.barplot(
    x='Failure Type',
    y='Count',
    data=plot_df,
    palette='magma',
    hue='Failure Type',
    legend=False
)

# 5. Add numbers on top of bars
for i, v in enumerate(plot_df['Count']):
    ax.text(i, v + 2, str(v), ha='center', fontsize=16, fontweight='bold')

# 6. Labels
plt.title('Figure 4.5: Distribution of Specific Failure Modes', fontsize=18, fontweight='bold', pad=20)
plt.ylabel('Frequency (Count)', fontsize=15, fontweight='bold')
plt.xlabel('Failure Mode', fontsize=15, fontweight='bold')

# 7. Save and Show
plt.savefig('Figure_4.5_Failure_Modes_BarChart.png', dpi=300, bbox_inches='tight')
plt.show()

# FIX 2: Corrected the print keys to match definitions exactly
print(f"HDF Count: {failure_data['HDF\n(Heat)']}")
print(f"OSF Count: {failure_data['OSF\n(Overstrain)']}")
# Out:
# HDF Count: 115
# OSF Count: 98

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Derived values based on Table 6.2 metrics [cite: 1041]
# TN=1829, FP=103, FN=10, TP=58
cf_matrix = np.array([[1829, 103],
                      [10, 58]])

# Labels
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_matrix.flatten()/np.sum(cf_matrix)]

# Combine labels for the box text
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in zip(group_names, group_counts, group_percentages)]
labels = np.asarray(labels).reshape(2,2)

# Plotting
plt.figure(figsize=(7, 5))
ax = sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues', cbar=True)

ax.set_title('Binary Fault Detection Confusion Matrix\n(1D-CNN with SMOTE)', fontsize=14)
ax.set_xlabel('Predicted Label', fontsize=12)
ax.set_ylabel('Actual Label', fontsize=12)

# Ticket labels - 0 is Normal, 1 is Failure
ax.xaxis.set_ticklabels(['Normal (0)', 'Failure (1)'])
ax.yaxis.set_ticklabels(['Normal (0)', 'Failure (1)'])

plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# ==========================================
# 1. INPUT DATA (Derived from Thesis Table 6.2)
# ==========================================
# Total Test Set: ~2000 samples (20% of 10,000)
# Class Imbalance: 96.6% Normal, 3.4% Failure
# 1D-CNN Metrics: Recall = 0.85, Precision = 0.36

# Derived Counts
TP = 58   # True Positives (Caught Failures)
FN = 10   # False Negatives (Missed Failures)
FP = 103  # False Positives (False Alarms)
TN = 1829 # True Negatives (Correctly Ignored)

# Create the Matrix
# Format: [[TN, FP], [FN, TP]]
cf_matrix = np.array([[TN, FP],
                      [FN, TP]])

# ==========================================
# 2. GENERATE SAFETY REPORT (TEXT OUTPUT)
# ==========================================
print("=== BINARY DETECTION SAFETY REPORT ===")
print(f"Total Test Samples: {TP + FN + FP + TN}")
print(f"--------------------------------------")
print(f"[SAFETY METRIC] True Positives (TP):  {TP}  (Failures Caught)")
print(f"[DANGER METRIC] False Negatives (FN): {FN}  (Failures Missed)")
print(f"--------------------------------------")
print(f"[COST METRIC]   False Positives (FP): {FP} (False Alarms)")
print(f"[EFFICIENCY]    True Negatives (TN):  {TN} (Correct Normals)")
print(f"--------------------------------------")
print(f"Calculated Recall (Safety):    {TP/(TP+FN):.2f} (Matches Thesis Table 6.2)")
print(f"Calculated Precision (Trust):  {TP/(TP+FP):.2f} (Matches Thesis Table 6.2)")
print("======================================\n")

# ==========================================
# 3. GENERATE CONFUSION MATRIX FIGURE
# ==========================================
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):

    # Labeling the box text
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels, group_counts, group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])

    # Plotting
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    plt.figure(figsize=figsize)
    sns.heatmap(cf, annot=box_labels, fmt="", cmap=cmap, cbar=cbar,
                xticklabels=categories, yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('Actual Class', fontsize=12, fontweight='bold')
        plt.xlabel('Predicted Class', fontsize=12, fontweight='bold')

    if title:
        plt.title(title, fontsize=14, fontweight='bold', pad=20)

# CONFIGURATION FOR THE PLOT
labels = ['True Neg','False Pos','False Neg','True Pos']
categories = ['Normal (0)', 'Failure (1)']
make_confusion_matrix(cf_matrix,
                      group_names=labels,
                      categories=categories,
                      figsize=(8, 6),
                      cmap='Blues',
                      title='Binary Fault Detection Confusion Matrix\n(1D-CNN Safety Layer)')

plt.show()
# Out:
# === BINARY DETECTION SAFETY REPORT ===
# Total Test Samples: 2000
# --------------------------------------
# [SAFETY METRIC] True Positives (TP):  58  (Failures Caught)
# [DANGER METRIC] False Negatives (FN): 10  (Failures Missed)
# --------------------------------------
# [COST METRIC]   False Positives (FP): 103 (False Alarms)
# [EFFICIENCY]    True Negatives (TN):  1829 (Correct Normals)
# --------------------------------------
# Calculated Recall (Safety):    0.85 (Matches Thesis Table 6.2)
# Calculated Precision (Trust):  0.36 (Matches Thesis Table 6.2)
# ...
